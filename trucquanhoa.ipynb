# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("data_visualize (1).xlsx")

# %%
data.head()
# Out:
#   Ngày liên hệ    Nguồn Tên Phụ huynh   Tên học sinh  Tuổi               Lớp  \
# 0   2023-05-01  Fanpage    Hương Suri            NaN   3.0               NaN
# 1   2023-05-01  Fanpage     Kiều Phan         Sỹ Quý  11.0               NaN
# 2   2023-05-06  Fanpage    Thúy Hà Lê      Bảo Ngọc    6.0               NaN
# 3   2023-05-08  Fanpage   Nguyễn Hiếu       Uyên Nhi  11.0   Home schooling
# 4   2023-05-08  Data cũ          Thúy  Phan Văn Tùng   7.0  2, sắp lên lớp 3
#
#    Tỉnh/Tp                               Thông tin ban đầu  \
# 0      NaN                             Liên hệ qua Fanpage
# 1      NaN                                             NaN
# 2      NaN                                             NaN
# 3      NaN  CON mình 11t, mình muốn tư vấn về khóa học VUI
# 4  Đà Nẵng                                             NaN
#
#   Giao cho nhân viên Sale       Trạng thái  ...  Kế hoạch tiếp theo  \
# 0                     Thu          Từ chối  ...      Ngừng chăm sóc
# ...

# %%
print(data.dtypes)
# Out:
# Ngày liên hệ                                 datetime64[ns]
# Nguồn                                                object
# Tên Phụ huynh                                        object
# Tên học sinh                                         object
# Tuổi                                                float64
# Lớp                                                  object
# Tỉnh/Tp                                              object
# Thông tin ban đầu                                    object
# Giao cho nhân viên Sale                              object
# Trạng thái                                           object
# Đã test                                               int64
# KQ test đầu vào                                      object
# Đánh giá KQ quả trình độ sau test đầu vào            object
# Khóa học                                             object
# Lịch học                                             object
# Nhật ký chăm sóc                                     object
# ...

# %%
print(data['Doanh thu thực thu'].unique())
# Out:
# [nan 1000000 7500000 7437500 5205400 5348000 5205000 5116000 5348600
#  7450000 2756000 2908900 9897200 10254638 2302200 4348600 3200000 4165000
#  5511600 2353360 2430100 5021680 2296500 2909000 4156250 3281250 4025000
#  2817040 3325400 2910000 8312500 7457500 4616000 2558000 5022000 4243750
#  4157000 5524000 7950000 3062000 2462000 525000 4375000 3050000 5358280
#  7711500 5360000 2000000 3188000 2755800 4280000 ' ' 7712000 9215000
#  2970140 5227880 5327880 5512000 2496000 2664000 4349000 5328000 4176000
#  3264000 4187000 18900000 3937500 4785000 2750000 4916400 4605000 3308000
#  5205600 4675000 5767800 1330000]
